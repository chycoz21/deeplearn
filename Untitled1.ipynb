# %% [markdown]
# <a href="https://colab.research.google.com/github/chycoz21/deeplearn/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
from keras.optimizers import Adam
from keras.models import Sequential #untuk bentuk model
from keras.layers import Conv2D,MaxPool2D,Flatten,Dense,Dropout,Input,AveragePooling2D #untuk layer
from keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img #untuk memproses citra
#from keras.applications import resnet50
from keras.models import Model
from tensorflow.keras.applications import ResNet50V2


# %matplotlib inline
from matplotlib import pyplot as plt #untuk visualisasi data
from matplotlib import image as mpimg

from sklearn.metrics import confusion_matrix
import seaborn as sn 
import numpy as np #struktur data
import tensorflow as tf

# %%
# !pip install resnet
# !pip install https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# Out:
# ...
#      |████████████████████████████████| 94.7 MB 42 kB/s
#   ERROR: Cannot unpack file /tmp/pip-unpack-biml2kky/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5 (downloaded from /tmp/pip-req-build-c4w5h7t4, content-type: application/octet-stream); cannot detect archive format
# ERROR: Cannot determine archive format of /tmp/pip-req-build-c4w5h7t4

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
data_dir = "/content/gdrive/MyDrive/archive/BreaKHis 400X/test"
print(os.listdir(data_dir))
# Out:
# ['benign', 'malignant']

# %%
# contoh citra yg benign
img_path="/content/gdrive/MyDrive/archive/BreaKHis 400X/test/benign/SOB_B_A-14-22549AB-400-001.png" 
gambar = mpimg.imread(img_path)
plt.imshow(gambar)

# %%
# contoh citra yg malignant
img_path="/content/gdrive/MyDrive/archive/BreaKHis 400X/test/malignant/SOB_M_DC-14-10926-400-004.png" 
gambar = mpimg.imread(img_path)
plt.imshow(gambar)

# %%
#total data = 27.558
dim = 128
batch = 32

datagen = ImageDataGenerator(rescale=1/255.0, validation_split=0.3,
    rotation_range=20,
    zoom_range=0.05,
    width_shift_range=0.05,
    height_shift_range=0.05,
    shear_range=0.05,
    horizontal_flip=True)

train_data = datagen.flow_from_directory(data_dir, target_size=(dim,dim), batch_size=batch, class_mode = 'categorical', subset = 'training')
validation_data = datagen.flow_from_directory(data_dir, target_size=(dim,dim), batch_size=batch, class_mode = 'categorical', subset = 'validation', shuffle=False)
# Out:
# Found 383 images belonging to 2 classes.
# Found 162 images belonging to 2 classes.

# %%
from keras.applications.efficientnet import EfficientNetB3

from keras.models import Model
from keras.layers import Input, Dense, Flatten, Dropout

inputCustom=Input(shape=(224,224,3))
net= EfficientNetB3(include_top=False, weights='imagenet', 
input_tensor=inputCustom)

net.summary()
# Out:
# Model: "efficientnetb3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_13 (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# rescaling_1 (Rescaling)         (None, 224, 224, 3)  0           input_13[0][0]
# __________________________________________________________________________________________________
# normalization_1 (Normalization) (None, 224, 224, 3)  7           rescaling_1[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 225, 225, 3)  0           normalization_1[0][0]
# __________________________________________________________________________________________________
# ...

# %%
EP = 30

model.compile(optimizer="adam", 
              loss="binary_crossentropy", 
              metrics=["accuracy"])

# %%
history = model.fit(train_data, validation_data=validation_data, epochs=EP)
# Out:
# Epoch 1/30
# 12/12 [==============================] - 152s 12s/step - loss: 3.9220 - accuracy: 0.5000 - val_loss: 4.9230 - val_accuracy: 0.5000
# Epoch 2/30
# 12/12 [==============================] - 102s 8s/step - loss: 4.8141 - accuracy: 0.5000 - val_loss: 4.9230 - val_accuracy: 0.5000
# Epoch 3/30
# 12/12 [==============================] - 103s 9s/step - loss: 4.6903 - accuracy: 0.5000 - val_loss: 4.9230 - val_accuracy: 0.5000
# Epoch 4/30
# 12/12 [==============================] - 103s 9s/step - loss: 4.7648 - accuracy: 0.5000 - val_loss: 4.9230 - val_accuracy: 0.5000
# Epoch 5/30
# 12/12 [==============================] - 103s 9s/step - loss: 4.8504 - accuracy: 0.5000 - val_loss: 4.9230 - val_accuracy: 0.5000
# Epoch 6/30
# 12/12 [==============================] - 104s 9s/step - loss: 4.7035 - accuracy: 0.5000 - val_loss: 4.9230 - val_accuracy: 0.5000
# Epoch 7/30
# ...

# %%
plt.style.use("ggplot")
plt.figure()

plt.plot(np.arange(0, EP), history.history["loss"], label="train_loss")
plt.plot(np.arange(0, EP), history.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, EP), history.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, EP), history.history["val_accuracy"], label="val_acc")

plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")

# %%
test_loss, test_acc = model.evaluate(validation_data)
# Out:
# 6/6 [==============================] - 10s 1s/step - loss: 4.9230 - accuracy: 0.5000

# %%
predictions = model.predict(validation_data)

# %%
def get_confusion_matrix(y_true, y_pred):
    n_classes = len(np.unique(y_true))
    conf = np.zeros((n_classes, n_classes))
    for actual, pred in zip(y_true, y_pred):
        conf[int(actual)][int(pred)] += 1
    return conf.astype('int')

# %%
conf = get_confusion_matrix

# %%
classes = [0, 1]
# plot confusion matrix

plt.title("Confusion Matrix")

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)

fmt = 'd'


plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 15.0, 'Predicted label')
